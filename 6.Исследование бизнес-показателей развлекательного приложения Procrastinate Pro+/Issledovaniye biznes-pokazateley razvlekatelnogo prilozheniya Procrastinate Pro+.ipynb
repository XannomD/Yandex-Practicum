# %% [markdown]
# # Исследование бизнес-показателей развлекательного приложения Procrastinate Pro+

# %% [markdown]
# Мы - маркетинговые аналитики развлекательного приложения Procrastinate Pro+. Несколько прошлых месяцев наш бизнес постоянно нес убытки - в привлечение пользователей была вложена куча денег, а толку никакого. Нам нужно разобраться в причинах этой ситуации.
#
# **Цель исследования** — Нам нужно разобраться в причинах сложившейся ситуации - почему потратили много денег, а результата нет.
#
# **Описание данных:**
# У нас в распоряжении есть лог сервера с данными о посещениях приложения новыми пользователями, зарегистрировавшимися в период с 2019-05-01 по 2019-10-27, выгрузка их покупок за этот период, а также статистика рекламных расходов.
#
# Нам предстоит изучить, как люди пользуются продуктом, когда они начинают покупать, сколько денег приносит каждый клиент, когда он окупается и какие факторы отричательно влияют на привлечение пользователей.

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc">
# <a href='#1. Изучение  и подготовка данных'>1. Изучение  и подготовка данных</a>
#
# <a href='#1.1  Загрузка и изучение данных'>1.1  Загрузка и изучение данных</a>
#
# <a href='#1.1.1 Вывод'>1.1.1 Вывод</a>
#
# <a href='#1.2  Предобработка данных'>1.2  Предобработка данных</a>
#
# <a href='#1.2.1  Вывод'>1.2.1  Вывод</a>
#
# <a href='#2  Создание функция для расчета и анализа LTV, ROI, удержания и конверсии'>2  Создание функция для расчета и анализа LTV, ROI, удержания и конверсии</a>
#
# <a href='#3  Исследовательский анализ данных'>3  Исследовательский анализ данных</a>
#
# <a href='#3.1  Создание пользовательских профилей'>3.1  Создание пользовательских профилей</a>
#
# <a href='#3.1.1  Вывод'>3.1.1  Вывод</a>
#
# <a href='#3.2  Изучение пользователей из различных стран'>3.2  Изучение пользователей из различных стран</a>
#
# <a href='#3.2.1  Вывод'>3.2.1  Вывод</a>
#
# <a href='#3.3  Изучение устройств, с которых заходят пользователи ( с которых чаще платят)'>3.3  Изучение устройств, с которых заходят пользователи ( с которых чаще платят)</a>
#
# <a href='#3.3.1  Вывод'>3.3.1  Вывод</a>
#
# <a href='#3.4  Изучение рекламных источников привлечения клиентов, определение самых выгодных'>3.4  Изучение рекламных источников привлечения клиентов, определение самых выгодных</a>
#
# <a href='#3.4.1  Вывод'>3.4.1  Вывод</a>
#
# <a href='#3.5  Вывод'>3.5  Вывод</a>
#
# <a href='#4  Маркетинговое исследование'>4  Маркетинговое исследование</a>
#
# <a href='#4.1  Определение общей суммы расходов на маркетинг. Изучение распределения траты по источникам / времени'>4.1  Определение общей суммы расходов на маркетинг. Изучение распределения траты по источникам / времени</a>
#
# <a href='#4.1.1  Вывод'>4.1.1  Вывод</a>
#
# <a href='#4.2  Средняя стоимость привлечения одного пользователя из каждого источника'>4.2  Средняя стоимость привлечения одного пользователя из каждого источника</a>
#
# <a href='#4.2.1  Вывод'>4.2.1  Вывод</a>
#
# <a href='#4.3  Вывод'>4.3  Вывод</a>
#
# <a href='#5  Оценка окупаемости рекламы'>5  Оценка окупаемости рекламы</a>
#
# <a href='#5.1  Анализ общей окупаемости рекламы'>5.1  Анализ общей окупаемости рекламы</a>
#
# <a href='#5.1.1  Вывод'>5.1.1  Вывод</a>
#
# <a href='#5.2  Анализ окупаемости рекламы с разбивкой по устройствам'>5.2  Анализ окупаемости рекламы с разбивкой по устройствам</a>
#
# <a href='#5.2.1  Вывод'>5.2.1  Вывод</a>
#
# <a href='#5.3  Анализ окупаемости рекламы с разбивкой по странам'>5.3  Анализ окупаемости рекламы с разбивкой по странам</a>
#
# <a href='#5.3.1  Вывод'>5.3.1  Вывод</a>
#
# <a href='#5.4  Анализ окупаемости рекламы с разбивкой по рекламным каналам'>5.4  Анализ окупаемости рекламы с разбивкой по рекламным каналам</a>
#
# <a href='#5.4.1  Вывод'>5.4.1  Вывод</a>
#
# <a href='#5.5  Анализ конверсии и удержания с разбивкой по устройствам, странам, рекламным каналам'>5.5  Анализ конверсии и удержания с разбивкой по устройствам, странам, рекламным каналам</a>
#
# <a href='#5.5.1  Конверсия по устройствам, странам и рекламным каналам'>5.5.1  Конверсия по устройствам, странам и рекламным каналам</a>
#
# <a href='#5.5.2 Удержание с разбивкой по устройствам, странам и рекламным каналам'>5.5.2 Удержание с разбивкой по устройствам, странам и рекламным каналам</a>
#
# <a href='#5.6  Вывод'>5.6  Вывод</a>
#
# <a href='#6  Общий вывод'>6  Общий вывод</a>

# %% [markdown]
# <a id='1. Изучение  и подготовка данных'></a>
# ## Изучение  и подготовка данных

# %% [markdown]
# <a id='1.1  Загрузка и изучение данных'></a>
# ### Загрузка и изучение данных

# %% [markdown]
# Импортируем все библиотеки, которые нам могут пригодиться:

# %%
import pandas as pd
import warnings 
warnings.simplefilter('ignore')
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats as st
from datetime import datetime, timedelta
import seaborn as sns

# %% [markdown]
# Прочитаем файлы, данные нам для проекта и изучим их:

# %%
visits=pd.read_csv('visits_info_short.csv')
orders=pd.read_csv('orders_info_short.csv')
costs=pd.read_csv('costs_info_short.csv')

# %%
visits.sample(5)
# Out:
#              User Id         Region   Device         Channel  \
# 51255   268813831578  United States      Mac        FaceBoom
# 285312  868352913711         France       PC         organic
# 100496  259189035297  United States  Android          TipTop
# 243916  963681245550             UK  Android  WahooNetBanner
# 304247  970661106086             UK  Android         organic
#
#               Session Start          Session End
# 51255   2019-06-23 09:53:54  2019-06-23 10:50:42
# 285312  2019-09-24 20:08:42  2019-09-24 22:48:58
# 100496  2019-08-07 04:07:40  2019-08-07 04:25:32
# 243916  2019-07-12 16:50:22  2019-07-12 16:57:47
# 304247  2019-10-21 23:24:53  2019-10-21 23:33:33

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %% [markdown]
# Таблица visits - лог сервера с информацией о посещениях сайта:
# * User Id — уникальный идентификатор пользователя,
# * Region — страна пользователя,
# * Device — тип устройства пользователя,
# * Channel — идентификатор источника перехода,
# * Session Start — дата и время начала сессии,
# * Session End — дата и время окончания сессии.

# %%
orders.sample(5)
# Out:
#             User Id             Event Dt  Revenue
# 2908   588191338194  2019-06-08 13:32:15     4.99
# 27351  565240421562  2019-10-28 06:11:48     4.99
# 27668  288106967023  2019-10-30 19:29:34     4.99
# 20746  420731170573  2019-09-28 09:26:44     4.99
# 27186  767779471280  2019-10-27 18:53:49     4.99

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %% [markdown]
# Таблица orders - информация о заказах:
# * User Id — уникальный идентификатор пользователя,
# * Event Dt — дата и время покупки,
# * Revenue — сумма заказа.

# %%
costs.sample(10)
# Out:
#               dt             Channel    costs
# 539   2019-10-27      RocketSuperAds   10.075
# 1435  2019-10-23  OppleCreativeMedia   13.250
# 49    2019-06-19            FaceBoom  144.100
# 463   2019-08-12      RocketSuperAds    5.915
# 204   2019-05-25        MediaTornado    7.920
# 1584  2019-09-22      WahooNetBanner   36.600
# 1027  2019-09-05          AdNonSense   13.650
# 1535  2019-08-04      WahooNetBanner   34.800
# 1441  2019-05-02      WahooNetBanner    7.200
# 1070  2019-10-18          AdNonSense   22.050

# %%
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# Таблица costs - информация о затратах на маркетинг:
# * Channel — идентификатор рекламного источника,
# * Dt — дата проведения рекламной кампании,
# * Costs — расходы на эту кампанию.

# %% [markdown]
# <a id='1.1.1 Вывод'></a>
# #### Вывод

# %% [markdown]
# Изучив представленные данные можем сказать следующее:
# * Наименование всех столбцов всех датафреймов необходимо привести к написанию в стиле змеиного и нижнего регистра ;
# * Преобразуем тип дат из соответствующих столбцов в нужный тип ( тавталогия, извиняюсь)
# * Какие то прям идеальные датасеты - нет пропусков, посмотрим в дальнейшем так ли это на самом деле.

# %% [markdown]
# <a id='1.2  Предобработка данных'></a>
# ### Предобработка данных

# %% [markdown]
# Переименуем столбцы:

# %%
visits=visits.rename(columns={'User Id':'user_id', 'Region':'region', 'Device':'device', 
                                'Channel':'channel', 'Session Start':'session_start', 'Session End':'session_end'})
visits.columns
# Out:
# Index(['user_id', 'region', 'device', 'channel', 'session_start',
#        'session_end'],
#       dtype='object')

# %%
orders=orders.rename(columns={'User Id':'user_id', 'Event Dt':'event_dt', 'Revenue':'revenue'})
orders.columns
# Out:
# Index(['user_id', 'event_dt', 'revenue'], dtype='object')

# %%
costs.columns = costs.columns.str.lower()
# здесь нам нужно только в нижний регистр перевести написание,можно не использовать 'rename' 
costs.columns
# Out:
# Index(['dt', 'channel', 'costs'], dtype='object')

# %% [markdown]
# Так как у нас во всех датасетах тип даты "non-null object", то приведем это к нужному нам формату:

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB

# %%
orders['event_dt'] =pd.to_datetime(orders['event_dt'])
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB

# %%
costs['dt'] = pd.to_datetime(costs['dt']).dt.date
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# Проверим наличе явных дубликатов:

# %%
print ('Дубликатов в таблице visits:', visits.duplicated().sum())
print ('Дубликатов в таблице orders:', orders.duplicated().sum())
print ('Дубликатов в таблице costs:', costs.duplicated().sum())
# Out:
# Дубликатов в таблице visits: 0
# Дубликатов в таблице orders: 0
# Дубликатов в таблице costs: 0

# %%
visits.isna().sum()
# Out:
# user_id          0
# region           0
# device           0
# channel          0
# session_start    0
# session_end      0
# dtype: int64

# %%
orders.isna().sum()
# Out:
# user_id     0
# event_dt    0
# revenue     0
# dtype: int64

# %%
costs.isna().sum()
# Out:
# dt         0
# channel    0
# costs      0
# dtype: int64

# %% [markdown]
# <a id='1.2.1  Вывод'></a>
# #### Вывод

# %% [markdown]
# * Привели даты к нужному типу данных
# * Привели наименования столбцов к правильному написанию ( тепепрь таблицы выглядят аккуратнее и правильно)
# * Проверили на наличие дубликатов и пропусков - они отсутсвуют. ( прям получились идеальные данные, инженеры данных хорошо работаю в этой компании - все у них отлично, всем бы таких сотрудников^^)

# %% [markdown]
# <a id='2  Создание функция для расчета и анализа LTV, ROI, удержания и конверсии'></a>
# ## Создание функция для расчета и анализа LTV, ROI, удержания и конверсии

# %% [markdown]
# Напишем функцию, которая создает профили пользователей(плюс включим сразу расходы на рекламу для дальнейших расчетов):

# %%
def get_profiles(visits, orders, ad_costs):
    profiles = (
        visits.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())


    
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']
    
    profiles['dt'] = profiles['first_ts'].dt.date

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# Функция для расчёта LTV и ROI

# %%
def get_ltv(
    profiles,
    orders,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    result_raw = result_raw.merge(
        orders[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        result = result.fillna(0).cumsum(axis=1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )
        roi = result.div(cac['cac'], axis=0)
        roi = roi[~roi['cohort_size'].isin([np.inf])]
        roi['cohort_size'] = cohort_sizes
        roi['cac'] = cac['cac']
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]
        return result, roi

    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )
    if 'cohort' in dimensions:
        dimensions = []
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# Воспользуемся в дальнейшем функцией для визуализации LTV и ROI

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=14):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()
    
def filter_data(df, window):
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# Функция для расчета конверсии:

# %%
def get_conversion(
    profiles,
    orders,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        orders.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis=1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# Функция для анализа удержания:

# %%
def get_retention(
    profiles,
    visits,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        visits[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # рассчитываем удержание
    # новый вариант с dimensions
    result_grouped = result_raw.pivot_table(
        index=dimensions,  # заменили dt
        columns='lifetime',
        values='user_id',
        aggfunc='nunique',
    )
    cohort_sizes = (
        result_raw.groupby(dimensions)  # заменили dt
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'cohort_size'})
    )
    result_grouped = cohort_sizes.merge(
        result_grouped, on=dimensions, how='left'  # заменили dt
    ).fillna(0)
    result_grouped = result_grouped.div(result_grouped['cohort_size'], axis=0)

    # исключаем все лайфтаймы, превышающие горизонт анализа
    result_grouped = result_grouped[
        ['cohort_size'] + list(range(horizon_days))
    ]

    # восстанавливаем столбец с размерами когорт
    result_grouped['cohort_size'] = cohort_sizes

    # возвращаем таблицу удержания и сырые данные
    return result_raw, result_grouped

# %% [markdown]
# <a id='3  Исследовательский анализ данных'></a>
# ## Исследовательский анализ данных

# %% [markdown]
# <a id='3.1  Создание пользовательских профилей'></a>
# ### Создание пользовательских профилей

# %% [markdown]
# Создадим профили пользователей с помощью функции def get_profiles(visits, orders, costs), которую мы создали выше:

# %%
profiles = get_profiles(visits, orders, costs)

profiles.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %% [markdown]
# Определим минимальную и максимальную даты привлечения пользователей:

# %%
print('Минимальная дата привлечения пользователей:', profiles['dt'].min())
print('Максимальная дата привлечения пользователей:', profiles['dt'].max())
# Out:
# Минимальная дата привлечения пользователей: 2019-05-01
# Максимальная дата привлечения пользователей: 2019-10-27

# %% [markdown]
# <a id='3.1.1  Вывод'></a>
# #### Вывод

# %% [markdown]
# Судя по всему выборка постороена на данных за период с мая 2019 по 27 октября 2019 г.
#
# Далее рассмотрим, по каким каналам и из каких стран приходчт пользователи в наше приложение.

# %% [markdown]
# <a id='3.2  Изучение пользователей из различных стран'></a>
# ### Изучение пользователей из различных стран

# %% [markdown]
# Выясним, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей:

# %%
profiles.groupby('region').agg({'user_id': 'nunique', 'payer': [
    'sum', 'mean']}).sort_values(by='region', ascending = False)\
.rename(columns={'nunique': 'Всего пользователей','sum': 'Те кто платит', 'mean': '% платящих'})
# Out:
#                           user_id         payer
#               Всего пользователей Те кто платит % платящих
# region
# United States              100002          6902   0.069019
# UK                          17575           700   0.039829
# Germany                     14981           616   0.041119
# France                      17450           663   0.037994

# %% [markdown]
# <a id='3.2.1  Вывод'></a>
# #### Вывод

# %% [markdown]
# Основной поток клиентов к нам в приложение идет из США, они же и лидируют по оплате - 6,9 % всех пользователей что то оплатили в приложении.
#
# Великобритания и Франция находятся примерно на одно уровне - примерно, по 15 тысю человек пришло с этих стран в приложение. Платящих пользователей из этих стран примерно поровну: 3,98 и 3,79 % соответственно.
#
# В аутсайдерах оказалась Германия: из данной страны пришло самое малое количество пользователей, однако процент платящих пользователей из этой страны больше чем из Англии и Франции, и составляет 4,11 %.

# %% [markdown]
# <a id='3.3  Изучение устройств, с которых заходят пользователи ( с которых чаще платят)'></a>
# ### Изучение устройств, с которых заходят пользователи ( с которых чаще платят)

# %%
profiles.groupby('device').agg({'user_id': 'nunique', 'payer': [
    'sum', 'mean']}).sort_values(by='device', ascending = False)\
.rename(columns={'nunique': 'Всего пользователей','sum': 'Те кто платит', 'mean': '% платящих'})
# Out:
#                     user_id         payer
#         Всего пользователей Те кто платит % платящих
# device
# iPhone                54479          3382   0.062079
# PC                    30455          1537   0.050468
# Mac                   30042          1912   0.063644
# Android               35032          2050   0.058518

# %% [markdown]
# <a id='3.3.1  Вывод'></a>
# #### Вывод

# %% [markdown]
# Получаем, что основнная масса пользователей нешего приложения владельцы iphone, следом идут пользователи Android-устройств. Польователей на MAC и PC - примерно одинаковое количество.
#
# В лидерах по конвертации всех пользователей в платящих пользователи iPhone и Mac, с 6,21 % и 6,36 %. Следом идут пользователи РС (5,05 %) и замыкают список пользователи Android с 5,85 %.

# %% [markdown]
# <a id='3.4  Изучение рекламных источников привлечения клиентов, определение самых выгодных'></a>
# ### Изучение рекламных источников привлечения клиентов, определение самых выгодных

# %%
profiles.groupby('channel').agg({'user_id': 'nunique', 'payer': [
    'sum', 'mean']}).sort_values(by='channel', ascending = False)\
.rename(columns={'nunique': 'Всего пользователей','sum': 'Те кто платит', 'mean': '% платящих'})
# Out:
#                                user_id         payer
#                    Всего пользователей Те кто платит % платящих
# channel
# organic                          56439          1160   0.020553
# lambdaMediaAds                    2149           225   0.104700
# YRabbit                           4312           165   0.038265
# WahooNetBanner                    8553           453   0.052964
# TipTop                           19561          1878   0.096007
# RocketSuperAds                    4448           352   0.079137
# OppleCreativeMedia                8605           233   0.027077
# MediaTornado                      4364           156   0.035747
# LeapBob                           8553           262   0.030633
# FaceBoom                         29144          3557   0.122049
# AdNonSense                        3880           440   0.113402

# %% [markdown]
# <a id='3.4.1  Вывод'></a>
# #### Вывод

# %% [markdown]
# Судя по полученным данным самыми популярными каналами привлечения клиентов являются: organic ( он самый лучший, так как бесплатный), FaceBoom и TipTop. Однако самая большая конвертация пользователей в платящих у каналов: FaceBoom (12,2 %), AdNonSense (11,3 %) и lambdaMediaAds (10,5%). Самая маленькая конвертация в платящих пользователей происходит у тех пользователей, которые пришли по каналам organic, YRabbit и LeapBob. Не смотря на то, что канал organic приводит больше всех пользователей, но конверсия у этих пользователей одна из самых низких ( количество не всегда значит качество).

# %% [markdown]
# <a id='3.5  Вывод'></a>
# ### Вывод

# %% [markdown]
# 1. Мы рассматриваем выборку из пользователей, которые совершили действия в нашем приложении в период с 01.05.2019 по 27.10.2019 г.
# 2. Пользователи из United States - основной наш поток клиентов, Germany - поставляет нам самое меньше количесво пользователей.
# 3. Основнная масса пользователей нешего приложения владельцы iphone, следом идут пользователи Android-устройств. Польователей на MAC и PC - примерно одинаковое количество
# 4. Самыми популярными каналами привлечения клиентов являются: organic, FaceBoom и TipTop. Однако самая большая конвертация пользователей в платящих у каналов: FaceBoom (12,2 %), AdNonSense (11,3 %) и lambdaMediaAds (10,5%). Самая маленькая конвертация в платящих пользователей происходит у тех пользователей, которые пришли по каналам organic, YRabbit и LeapBob

# %% [markdown]
# <a id='4  Маркетинговое исследование'></a>
# ## Маркетинговое исследование

# %% [markdown]
# <a id='4.1  Определение общей суммы расходов на маркетинг. Изучение распределения траты по источникам / времени'></a>
# ### Определение общей суммы расходов на маркетинг. Изучение распределения траты по источникам / времени

# %% [markdown]
# Рассмотрим распределение затрат на маркетинг по каналам:

# %%
costs_channel = costs.groupby('channel')['costs'].sum().reset_index()
costs_channel['pecent']=(costs_channel['costs']/costs_channel['costs'].sum()*100).round(2)
display(costs_channel)
print('Общая сумма затрат на рекламу:', costs_channel['costs'].sum().round(2))
# Out:
#               channel     costs  pecent
# 0          AdNonSense   3911.25    3.71
# 1            FaceBoom  32445.60   30.75
# 2             LeapBob   1797.60    1.70
# 3        MediaTornado    954.48    0.90
# 4  OppleCreativeMedia   2151.25    2.04
# 5      RocketSuperAds   1833.00    1.74
# 6              TipTop  54751.30   51.90
# 7      WahooNetBanner   5151.00    4.88
# 8             YRabbit    944.22    0.90
# 9      lambdaMediaAds   1557.60    1.48
# Общая сумма затрат на рекламу: 105497.3

# %%
plt.figure(figsize=(7,7))
plt.pie(x=costs_channel['costs'], labels=costs_channel['channel'], autopct="%1.0f")
plt.title('Распределение расходов на маркетинг по каналам');
plt.show()

# %% [markdown]
# Основные затраты на маркетинг идут на следубщие каналы: TipTop и FaceBoom, 51,9 % и 30,75 % соответственно. Мы помним, что TipTop - третий канал, а FaceBoom - второй канал по привлечению новых пользователей.

# %% [markdown]
# Посмотрим как распределены затраты по месяцам:

# %%
costs_month=costs.groupby(costs['dt'].astype('datetime64[M]'))['costs'].sum().round(2).reset_index()
display(costs_month)
print('Общая сумма затрат на рекламу:', costs_month['costs'].sum().round(2))
# Out:
#           dt     costs
# 0 2019-05-01   9978.57
# 1 2019-06-01  15090.04
# 2 2019-07-01  16447.06
# 3 2019-08-01  20657.87
# 4 2019-09-01  22441.34
# 5 2019-10-01  20882.42
# Общая сумма затрат на рекламу: 105497.3

# %%
fig, ax = plt.subplots()
ax.bar(costs_month['dt'].dt.month, costs_month['costs'])
plt.xlabel('Месяц')
plt.ylabel('Сумма затрат')
plt.grid()
plt.title('Распределение затрат на маркетинг по меясцам')
fig.set_figwidth(10)    
fig.set_figheight(6)  
plt.show()

# %% [markdown]
# Судя по данным, затраты на маркетинг росли каждый месяц. Напомню, что у нас за октябрь месяц данный на 27.10.2019 г. - возможно в октябре затраты на рекламу были бы больше за целый месяц ( чем например в сентяре), если бы мы учли целый месяц.

# %% [markdown]
# Посчитаем стоимость рекламы по каждому каналу по месячно:

# %%
coast_on_channel_month=costs.copy(deep=True)
coast_on_channel_month['dt']=pd.to_datetime(coast_on_channel_month['dt']).dt.month
coast_on_channel_month=pd.pivot_table(coast_on_channel_month,index=['dt'], columns='channel',values='costs', aggfunc='sum').\
    query('dt').reset_index().rename(columns={'dt':'month'})
display(coast_on_channel_month.head(10))
# Out:
# channel  month  AdNonSense  FaceBoom  LeapBob  MediaTornado  \
# 0            5     1169.70    3524.4   140.28        238.56
# 1            6      538.65    5501.1   314.58        138.00
# 2            7      504.00    5294.3   313.53        138.48
# 3            8      579.60    6274.4   369.81        154.56
# 4            9      581.70    6114.9   343.98        144.72
# 5           10      537.60    5736.5   315.42        140.16
#
# channel  OppleCreativeMedia  RocketSuperAds   TipTop  WahooNetBanner  YRabbit  \
# 0                    169.75         577.980   2981.0           418.8   299.70
# 1                    370.00         325.715   6675.6           921.0   106.20
# 2                    366.50         252.070   8410.2           851.4    97.38
# 3                    439.25         253.110  11202.0          1040.4   124.74
# 4                    427.75         218.400  13232.5           977.4   152.79
# ...

# %% [markdown]
# <a id='4.1.1  Вывод'></a>
# #### Вывод

# %% [markdown]
# 1. TipTop и FaceBoom, 51,9 % и 30,75 % - основные каналы, на которые идут рекламные затраты.
# 2. Начиная с мая затраты на маркетинг росли ежемесячно, пик затрат пришелся на сентябрь, однако следует помнить, что у нас данные не завесь октябрь и возможнос если октябрь прошел полностью - то затраты были больше чем в сентябре.
# 3. По каналу TipTop - сумма затрат стабильно растет какждый месяц ( проверим дальше будет ли так же значительно увеличеваться количество пользователей, пришедших по этому каналу)

# %% [markdown]
# <a id='4.2  Средняя стоимость привлечения одного пользователя из каждого источника'></a>
# ### Средняя стоимость привлечения одного пользователя из каждого источника

# %% [markdown]
# Посчитаем среднюю стоимость привлечения одного клиента по месяцам для каждого источника:

# %%
costs_one_month=profiles.copy(deep=True)
costs_one_month['dt']=pd.to_datetime(costs_one_month['dt']).dt.month
costs_one_month=costs_one_month.pivot_table(index='dt', columns='channel', values='acquisition_cost', aggfunc='mean').reset_index().\
rename(columns={'dt':'month'})
costs_one_month.head(10)
# Out:
# channel  month  AdNonSense  FaceBoom   LeapBob  MediaTornado  \
# 0            5    1.027856  1.105868  0.201842      0.226768
# 1            6    1.012500  1.116748  0.211696      0.218354
# 2            7    0.992126  1.113652  0.209859      0.215365
# 3            8    0.995876  1.112088  0.210478      0.224325
# 4            9    1.004663  1.114434  0.210385      0.210962
# 5           10    0.993715  1.114316  0.212261      0.211722
#
# channel  OppleCreativeMedia  RocketSuperAds    TipTop  WahooNetBanner  \
# 0                  0.243544        0.549411  1.357468        0.577655
# 1                  0.249831        0.498798  2.077684        0.598441
# 2                  0.251544        0.417334  2.650552        0.607709
# 3                  0.250142        0.354000  3.011290        0.605941
# 4                  0.250586        0.302493  3.480405        0.601477
# 5                  0.250829        0.293056  3.543535        0.609314
#
# channel   YRabbit  lambdaMediaAds  organic
# ...

# %% [markdown]
# Из полученных данных видно, что стоимость привлечения одного клиента по каждому каналу примерно колеблется на одном уровне от меясца к месяцу, но вот TipTop - каждый месяц стоймость привлечения растет.
#
# Для наглядности визуализируем данную таблицу:

# %%
plt.figure(figsize=(15,10))
plt.grid(True)
plt.title('Динамика САС по каналам привлечения')

i=0
for column in costs_one_month.columns[1:]:
    plt.plot(costs_one_month.month.to_list(), costs_one_month[column].to_list(), label=column);
    i+=1

plt.grid(True)
plt.xlabel('Месяц привлечения')    
plt.ylabel('CAC, $')
plt.legend()
plt.show()

# %% [markdown]
# На графике так же заметен рост САС по каналу привлечения TipTop. Интересно. Может быть затраты на этот канал не только росли, но еще и уменьшалось количество пользователей, которые по нему приходили в приложение. Проверим это.

# %%
user_on_channel=profiles.copy(deep=True)
user_on_channel['dt']=pd.to_datetime(user_on_channel['dt']).dt.month
user_on_channel=pd.pivot_table(user_on_channel,index=['dt'], columns='channel',values='user_id', aggfunc='count').\
    query('dt').reset_index().rename(columns={'dt':'month'})
display(user_on_channel.head(10))
# Out:
# channel  month  AdNonSense  FaceBoom  LeapBob  MediaTornado  \
# 0            5        1138      3187      695          1052
# 1            6         532      4926     1486           632
# 2            7         508      4754     1494           643
# 3            8         582      5642     1757           689
# 4            9         579      5487     1635           686
# 5           10         541      5148     1486           662
#
# channel  OppleCreativeMedia  RocketSuperAds  TipTop  WahooNetBanner  YRabbit  \
# 0                       697            1052    2196             725     1066
# 1                      1481             653    3213            1539      581
# 2                      1457             604    3173            1401      603
# 3                      1756             715    3720            1717      650
# 4                      1707             722    3802            1625      714
# 5                      1507             702    3457            1546      698
#
# ...

# %% [markdown]
# Да, был спад в последний месяц ( возможно из-за того что месяц не полный, но и затраты не за весь месяц наверное), но существенного уменьшения прибытия пользователей по каналу TipTop не было. Значит получается, что увеличение затрат на данный канал не выстрелило и больше пользователей не "повалило".

# %% [markdown]
# И посчтиаем за одно среднюю стоимость одного пользователя в целом по каналам:

# %%
profiles.query('channel != "organic"').groupby('channel').agg({'acquisition_cost':'mean'}).sort_values(by='acquisition_cost', ascending = False)
# Out:
#                     acquisition_cost
# channel
# TipTop                      2.799003
# FaceBoom                    1.113286
# AdNonSense                  1.008054
# lambdaMediaAds              0.724802
# WahooNetBanner              0.602245
# RocketSuperAds              0.412095
# OppleCreativeMedia          0.250000
# YRabbit                     0.218975
# MediaTornado                0.218717
# LeapBob                     0.210172

# %% [markdown]
# Тут ничего нового: TipTop - в лидерах.

# %% [markdown]
# Расчитаем среднюю стоимость привлечения одного пользователя на весь проект:

# %%
print('Средняя стоимость одного пользователя проекта:', round(profiles.query('channel != "organic"')['acquisition_cost'].mean(),2))
# Out:
# Средняя стоимость одного пользователя проекта: 1.13

# %% [markdown]
# <a id='4.2.1  Вывод'></a>
# #### Вывод

# %% [markdown]
# 1. Стоимость привлечения одного клиента по каждому каналу примерно колеблется на одном уровне от меясца к месяцу, но вот TipTop - каждый месяц стоймость привлечения растет
# 2. TipTop - самый дорогой канал по привлечению клиентов, но в то же время и  один из самых "широких"

# %% [markdown]
# <a id='4.3  Вывод'></a>
# ### Вывод

# %% [markdown]
# 1. TipTop и FaceBoom, 51,9 % и 30,75 % - основные каналы, на которые идут рекламные затраты.
# 2. Начиная с мая затраты на маркетинг росли ежемесячно, пик затрат пришелся на сентябрь, однако следует помнить, что у нас данные не за весь октябрь и возможнос если октябрь прошел полностью - то затраты были больше чем в сентябре.
# 3. Стоимость привлечения одного клиента по каждому каналу примерно колеблется на одном уровне от меясца к месяцу, но вот TipTop - каждый месяц стоймость привлечения растет. Топы по стоимости привлечения одного клиента следующие каналы: TipTop, FaceBoom, AdNonSense.

# %% [markdown]
# <a id='5  Оценка окупаемости рекламы'></a>
# ## Оценка окупаемости рекламы

# %% [markdown]
# <a id='5.1  Анализ общей окупаемости рекламы'></a>
# ### Анализ общей окупаемости рекламы

# %% [markdown]
# Проанализируем общую окупаемость рекламы. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
observation_date = datetime(2019, 11, 1).date()
horizon_days = 14
profiles = profiles.query('channel != "organic"')

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(
    profiles.query('channel != "organic"'), orders, observation_date, horizon_days)
plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon_days)

# %% [markdown]
# <a id='5.1.1  Вывод'></a>
# #### Вывод

# %% [markdown]
# 1. LTV с каждым месяец растет, что не может не радовать - каждый месяц клиенты приносят приложению больше денег.
# 2. Если рассматривать LTV в динамики, то на 14 день объем выручки, который приносят пользователи, привлеченные в разные месяцы достаточно сильно колеблится.
# 3. Стоимость привлечения клинетов от месяца к месяцу увеличивается. Мы это уже посмотрели чуть выше. Но мы помним, что в среднем уровень стоимости привлечения клиентов по большинству каналов колеблется в пределах одной величины и только по каналу TipTop стоимость постоянно расчет. Дальше еще разок посмотрим на эту метрику в разбивке по каналам.
# 4. Общей окупаемости пользователей, пришедших по всем каналам на 14 день не произошло.
# 5. По последнему графику мы видим, что вначале ислледования ( май) реклама окупалась в сумме по всем пользователям на 14 день, однако начиная с июyя месяца реклама перестала окупаться.

# %% [markdown]
# <a id='5.2  Анализ окупаемости рекламы с разбивкой по устройствам'></a>
# ### Анализ окупаемости рекламы с разбивкой по устройствам

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(
    profiles.query('channel != "organic"'), orders, observation_date, horizon_days, dimensions=['device'])
plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon_days)

# %% [markdown]
# <a id='5.2.1  Вывод'></a>
# #### Вывод

# %% [markdown]
# 1. LTV с каждым месяцем растет по всем устройстам. Пользователи PC приносят приложению меньше всего денег. Лидерами являются владельцы Iphone и Mac.
# 2. Динамика LTV в разбивке по устростройствам так же подвержена сильным колебаниям в зависимости от месяца привлечения.
# 3. Динамика CAC показывает, что стоимость привлечения расчет с каждым месяцем по всем устройствам, однако на владельцев MAC и iphone разработчики тратят больше всего денег. Пользователи ПК могут похватстаться самыми малыми затратами, на их привлечение.
# 4. Окупаемость пользователей по каналу PC имеет место быть, а вот остальные пользователи не окупаются. Мы помним что в целом окупаемости на 14 день нет  - пользователи ios систем "тянут" окупаемость на дона(.
# 5. К концу периода ни один из видов устройства ( с которого заходили пользователи в приложение) не окупился.

# %% [markdown]
# <a id='5.3  Анализ окупаемости рекламы с разбивкой по странам'></a>
# ### Анализ окупаемости рекламы с разбивкой по странам

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(
    profiles.query('channel != "organic"'), orders, observation_date, horizon_days, dimensions=['region'])
plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon_days)

# %% [markdown]
# <a id='5.3.1  Вывод'></a>
# #### Вывод

# %% [markdown]
# Так, а это уже инстересно.
#
# 1. Пользователи из США составляют основную массу из всех ( мы раньше смотрели, пользователей из США 67%) и соотвественно LTV по данным пользоватлем наивысший. Пользователи из Франции закрывают список.
# 2. Динамика LTV по месяцам на 14 день так же существенно колеблется, ничего нового.
# 3. Вот с этого момента начинается самое интересное: самые высоки затраты на привлечение пользователей - для страны США ( притом в несколько раз!). Остальные страны находятся на одном уровне и не растут со временем, в отличие от США.
# 4. И что мы видим, что окупаемость имеется по всем странам привлечения пользователей, кроме США, а с учетом того что пользователи из США - это 67% всех пользователей, то получается в общей массе - это они тянут на дно вю маркетинговую кампанию по неокупаемости.
# 5. По динамике аналогичная ситуация, пользователи США не окупаются на 14 день ( в мае июне еще окупались конечно, но потом нет). Пользоватле остальных стран во всех месяцах в динамике были выше порога окупаемости.

# %% [markdown]
# <a id='5.4  Анализ окупаемости рекламы с разбивкой по рекламным каналам'></a>
# ### Анализ окупаемости рекламы с разбивкой по рекламным каналам

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=['channel'])
plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon_days)

# %% [markdown]
# <a id='5.4.1  Вывод'></a>
# #### Вывод

# %% [markdown]
# 1. Следуя тенденции с каждым месяцем LTV растет так же и по каналам привлечения. В лидерах lambdaMediaAds и TipTop. Канал Orgsnic - с самыми маленькими показателями, но он и бесплатный - в этом его прелесть.
# 2. Динамика LTV по каналам привлечения следует тенденции что и по всем остальным показателям - колеблется от месяца к месяцу. Особенно большие колебания заметны у такого канала как lambdaMediaAds, по остальным каналам колебания не такой сильной амплитуды.
# 3. По поводу стоимости привлечения пользователей по каналам мы уже разговаривали, и знаем, что пользвоатели, пришедшие через канал TipTop, имеют самую большую стоимость, которая росла с каждым месяцем ( и росла сильно). стоимость привлечения пользователей по другим каналам оставалась примерно на одном уровне.
# 4. Окупаемость пользователей, пришедших через каналы TipTop, FaceBoom и AdNonSense так и не произошла на 14 день. Пользователи, пришедшие по другим каналам, на 14 дней показали окупаемость.

# %% [markdown]
# Предлагаю глянуть на данные в целом без США и отдельно без канала привлечения TipTop:

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(
     profiles.query('region != "United States"'), orders, observation_date, horizon_days)
plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon_days)

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(
     profiles.query('channel != "organic" & region != "United States"'), orders, observation_date, horizon_days)
plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon_days)

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(
     profiles.query('channel != "TipTop"'), orders, observation_date, horizon_days)
plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon_days)

# %%
profiles.query('region == "United States"').groupby('channel').agg({'user_id': 'nunique', 'payer': [
    'sum', 'mean']}).sort_values(by='channel', ascending = False)\
.rename(columns={'nunique': 'Всего пользователей','sum': 'Те кто платит', 'mean': '% платящих'})
# Out:
#                            user_id         payer
#                Всего пользователей Те кто платит % платящих
# channel
# YRabbit                       4312           165   0.038265
# TipTop                       19561          1878   0.096007
# RocketSuperAds                4448           352   0.079137
# MediaTornado                  4364           156   0.035747
# FaceBoom                     29144          3557   0.122049

# %% [markdown]
# Итак, что мы получили. Проблемы у нас находятся в двух местах - это пользователи из США и канал привлечения TipTop. Судя по данным на пользователей США был полностью нацелены рекалмные источники FaceBoom и TipTop, которые не оправдали ожидаения и приведя всю маркетинговую кампанию в убыток.

# %% [markdown]
# Предлагаю глянуть на данные в только по  США и отдельно по каналу привлечения TipTop:

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(
     profiles.query('region == "United States"'), orders, observation_date, horizon_days)
plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon_days)

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(
     profiles.query('region == "United States" & channel != "organic"'), orders, observation_date, horizon_days)
plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon_days)

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(
     profiles.query('channel == "TipTop"'), orders, observation_date, horizon_days)
plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon_days)

# %% [markdown]
# То что мы и предполагали, окупаемости по каналу TipTop и пользователям из США не происходит. Однако беда началась в июне месяце.

# %% [markdown]
# <a id='5.5  Анализ конверсии и удержания с разбивкой по устройствам, странам, рекламным каналам'></a>
# ### Анализ конверсии и удержания с разбивкой по устройствам, странам, рекламным каналам

# %% [markdown]
# <a id='5.5.1  Конверсия по устройствам, странам и рекламным каналам'></a>
# #### Конверсия по устройствам, странам и рекламным каналам

# %% [markdown]
# Конверсия в целом по выборке:

# %%
conversion_raw, conversion, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days)

plt.figure(figsize=(30,10))


report = conversion.drop(columns=['cohort_size'])


sns.heatmap(
    report, annot=True, fmt='.2%', ax=plt.subplot(1, 2, 1)
)
plt.title('Тепловая карта конверсии')


report.T.plot(
    grid=True, xticks=list(report.columns.values), ax=plt.subplot(1, 2, 2)
)
plt.title('Кривая конверсии')

plt.show()

# %% [markdown]
# Конверсия по устройствам:

# %%
conversion_raw, conversion, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=['device'])

plt.figure(figsize=(30,10))


report = conversion.drop(columns=['cohort_size'])


report.T.plot(
    grid=True, xticks=list(report.columns.values), ax=plt.subplot(1, 2, 2)
)
plt.title('Кривая конверсии')

sns.heatmap(
    report, annot=True, fmt='.2%', ax=plt.subplot(1, 2, 1)
)
plt.title('Тепловая карта конверсии')
plt.show()

# %% [markdown]
# Самая высокая конверсия у пользователей iphone и MAC. Хуже всего конвертируются в платящих пользователей пользователи ПК.

# %% [markdown]
# Конверсия по регионам:

# %%
conversion_raw, conversion, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=['region'])

plt.figure(figsize=(30,10))


report = conversion.drop(columns=['cohort_size'])


report.T.plot(
    grid=True, xticks=list(report.columns.values), ax=plt.subplot(1, 2, 2)
)
plt.title('Кривая конверсии')

sns.heatmap(
    report, annot=True, fmt='.2%', ax=plt.subplot(1, 2, 1)
)
plt.title('Тепловая карта конверсии')
plt.show()

# %% [markdown]
# Если рассматривать конверсию по регионам, то лучшая конверсия у пользоватлей США, что и не удивительно - это основные пользователи приложения, на которых нацелена основная трата денег. Пользователи Великобритании стартует в первый день лучше, чем пользователи Германии и Франции, но на 14 день итоговая конверсия ниже чем у двух других.

# %% [markdown]
# Конверсия по каналам привлечения:

# %%
conversion_raw, conversion, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=['channel'])

plt.figure(figsize=(30,10))


report = conversion.drop(columns=['cohort_size'])


report.T.plot(
    grid=True, xticks=list(report.columns.values), ax=plt.subplot(1, 2, 2)
)
plt.title('Кривая конверсии')

sns.heatmap(
    report, annot=True, fmt='.2%', ax=plt.subplot(1, 2, 1)
)
plt.title('Тепловая карта конверсии')
plt.show()

# %% [markdown]
# FaceBoom, AdNonSense, lambdaMediaAds - канала-лидеры по пользователям, которые переходят в состав платящих.
#
# Наш самый дорогостоящий канал - TipTop, находится на 4м месте. ( а ведь он самый дорогой и в него вливается очень много денег из рекламного бюджета).
#
# Самая хуждая конвертация у пользователей, пришедших через такие каналы как organic и OppleCreativeMedia.

# %% [markdown]
# <a id='5.5.2 Удержание с разбивкой по устройствам, странам и рекламным каналам'></a>
# #### Удержание с разбивкой по устройствам, странам и рекламным каналам

# %% [markdown]
# Посмотрим на удержание пользователей, в разбивке по каналам привлечения:

# %%
retention_raw, retention = get_retention(
     profiles, visits, observation_date, horizon_days, dimensions=['channel']
)
plt.figure(figsize=(30, 10))  # задаём размер сетки

# исключаем размеры когорт и удержание первого дня
report = retention.drop(columns=['cohort_size', 0])

for i, payer in enumerate(profiles['payer'].unique()):
    report.query('payer == @payer').droplevel('payer').T.plot(
        grid=True,  # добавляем сетку
        # отметки на оси X — названия колонок
        xticks=list(report.columns.values),
        ax=plt.subplot(1, 2, i + 1), # задаём расположение графиков
    )
    plt.xlabel('Лайфтайм')
    plt.title('Кривые удержания для payer = {}'.format(payer))

plt.show()

# %% [markdown]
# На графике удержания платящих пользователей выделяются organic и FaceBoom: удержание пользователей, пришедших по этим каналам, ниже чем по всем остальным. По остальным каналам наблюдается так же тенденция уменьшения удержания пользователей, пусть и не такая сильная, к 14 дню.
#
# Согласно второму графику, удержание неплатящих примерно одинаково для всех каналов привлечения.

# %% [markdown]
# Посмотрим на удержание пользователей, в разбивке по устройствам:

# %%
retention_raw, retention = get_retention(
     profiles, visits, observation_date, horizon_days, dimensions=['device']
)
plt.figure(figsize=(20, 6))  # задаём размер сетки

# исключаем размеры когорт и удержание первого дня
report = retention.drop(columns=['cohort_size', 0])

for i, payer in enumerate(profiles['payer'].unique()):
    report.query('payer == @payer').droplevel('payer').T.plot(
        grid=True,  # добавляем сетку
        # отметки на оси X — названия колонок
        xticks=list(report.columns.values),
        ax=plt.subplot(1, 2, i + 1), # задаём расположение графиков
    )
    plt.xlabel('Лайфтайм')
    plt.title('Кривые удержания для payer = {}'.format(payer))

plt.show()

# %% [markdown]
# На графике удержания платящих пользователей выделяется зеленая линия: на протяжении всех 14 лайфтаймов удержание пользователей ПК немного выше. Пользователи iphone и MAC к концу 14 дня показывают самые плохие результаты.
#
# Для не платящих пользователей, удержание примерно одинаковое по всем устройствам

# %% [markdown]
# Посмотрим на удержание пользователей, в разбивке по региона:

# %%
retention_raw, retention = get_retention(
     profiles, visits, observation_date, horizon_days, dimensions=['region']
)
plt.figure(figsize=(20, 6))  # задаём размер сетки

# исключаем размеры когорт и удержание первого дня
report = retention.drop(columns=['cohort_size', 0])

for i, payer in enumerate(profiles['payer'].unique()):
    report.query('payer == @payer').droplevel('payer').T.plot(
        grid=True,  # добавляем сетку
        # отметки на оси X — названия колонок
        xticks=list(report.columns.values),
        ax=plt.subplot(1, 2, i + 1), # задаём расположение графиков
    )
    plt.xlabel('Лайфтайм')
    plt.title('Кривые удержания для payer = {}'.format(payer))

plt.show()

# %% [markdown]
# Красная линия ( уже как тряпка для быка), пользвоатели США показывают самое плохое удержание за рассматриваемый период. В лидерах по удержанию это пользователи Великобритании и Франции.

# %% [markdown]
# Посмотрим на динамику конверсии на 14 день с разбивкой на регионы, устройства и каналу привлечения:

# %%
conversion_raw, conversion, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=['channel'])
plt.figure(figsize=(40,5))
report = (
    conversion_history[13]
    .reset_index()
    .pivot_table(index='dt', columns='channel', values=13, aggfunc='mean')
    .fillna(0)
)
# строим график
report.plot(grid=True, ax=plt.subplot(1, 2, 2))
plt.title('Динамика конверсии 14-го дня с разбивкой по каналам привлечения')

plt.show()

# %%
conversion_raw, conversion, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=['region'])
plt.figure(figsize=(40,5))
report = (
    conversion_history[13]
    .reset_index()
    .pivot_table(index='dt', columns='region', values=13, aggfunc='mean')
    .fillna(0)
)
# строим график
report.plot(grid=True, ax=plt.subplot(1, 2, 2))
plt.title('Динамика конверсии 14-го дня с разбивкой по странам')

plt.show()

# %%
conversion_raw, conversion, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=['device'])
plt.figure(figsize=(40,5))
report = (
    conversion_history[13]
    .reset_index()
    .pivot_table(index='dt', columns='device', values=13, aggfunc='mean')
    .fillna(0)
)
# строим график
report.plot(grid=True, ax=plt.subplot(1, 2, 2))
plt.title('Динамика конверсии 14-го дня с разбивкой устройствам')

plt.show()

# %% [markdown]
# <a id='5.6  Вывод'></a>
# ### Вывод

# %% [markdown]
# 1. Стоимость привлечения клинетов от месяца к месяцу увеличивается. Притом самый большой рост наблюдается для пользователей из США по каналу TipTop.
# 2. LTV растет в течение всего рассматриваемого периода, по всем направления ( по разбивке на устройства, региона и каналу привлеченияя).
# 3. В целом окупаемости не происходит, и в этом есть две причину: США и TipTop - эти два фактора "тянут на дно" весь маркетин и вгоняют его в минус.
# 4. Пользователи из США составляют самую большую долю из всех пользователей приложения ( привлеченны), но в тоже время они и самые дорогие, и цена каждый месяц растет и растет.
# 5. Каналы привлечения FaceBoom и TipTop - самые не эффективные, они "тянут" на дно всю окпуаемость.
# 6. Хоть пользователи из США и составляют значительную часть из всех пользователей, они же имеют и самые плохие показатели удержания.
# 7. Пользователи, пришедние в приложение через канал AdNonSense имеют самую лучшую конвертацию в платящих, на протяжении всего рассматриваего периода они стабильно переходили в статус платящих. Маркетолагам следует обратить на этот канал внимание.
# 8. Не смотря на то, что мы уже выяснилис, что пользователи из США имеют проблемы, они имеют очень хорошу конвертация в платящих клиентов, поэтому возможно если с ними получится решить проблемы - то они станут золотой жилой для приложения.
# 9. Если рассматривать пользователей по устройствам, то стоит приглядеться к пользователям Android - данные пользовтаели отлично переходят в статус платящих, самый плохой показатель у ПК-боярь.

# %% [markdown]
# <a id='6  Общий вывод'></a>
# ## Общий вывод

# %% [markdown]
# Из-за неэффективной и дорогой рекламы в США по каналам FaceBoom и TipTop наше приложение Procrastinate Pro+ приносит убытки своим разработчикам.
#
# Маркетолагам, необходимо изучить эти два показателя ( США и два канала привлчения) и определить, что с ними не так.
#
# В итоге можно сказать:
# 1. Реклама не окупается.
# 2. Каналы TipTop, FaceBoom и AdNonSense - убыточные ( особенно TipTop). Необходимо по ним провести отдельное "расследование" и выяснить с чем связана убыточность. Потому как на них приходится огромная часть расходов и вследствии их неокупаемости вся маркетинговая кампания терпит крах.
# 3. Пользователи iphone и MAC так же не окупаются, в отличие от других платформ.
# 4. Из стран опять выделется США, пользователи этой страны не окупаются, имеют самую высокую стоимость привлечения и у них самое низкое удержание, что сильно влияет на окупаемость проекта в целом.
#
# Считаю необходимо провести дополнительный анализ по следующим показателям:
# 1. Почему на каналы TipTop, FaceBoom и AdNonSense тратят такие деньги и они не окупаются, притом затраты увеличиваются каждый месяц ( особенно  по TipTop).
# 2. Почему пользвотели из США имеют имеют такое низкое удеражание.
# 3. Что происходит с пользователями iphone и MAC, возможно имеются какие то технические проблемы ( например с оплатой - анпример apple pay иногда не работает).
# 4. Обратить внимание на канал AdNonSense, который имеет лучшую конвертацию пользователей в платящих.
# 5. Пользователи из США, не смотря на все свои проблемы, имеют так же лучшую конвертацию в палтящих пользователей, поэтому стоит уделить им особое внимание.
# 6. Если рассматривать пользователей по устройствам, то стоит приглядеться к пользователям Android - данные пользователи отлично переходят в статус платящих, самый плохой показатель у ПК-боярь.
# 7.Предлагаю так же часть рекламных затрат с канала TipTop (или все затраты с этого канала) и частично с канала FaceBoom ( нельзя его польностью исключить, по этому каналу самая высокая конверсия превращения пользователей в платящих, 12,2 %. Возможно вначале просто снизить затраты и посмотреть на результат) перенести:
# * на канал RocketSuperAds, который отличается чуть ли не лучшим удержанием пользователей. Так же данный канал может похватстаться конверсией пользователей в платящих в размере 7,9 %. Этот канала так же ( как и TipTop) полностью нацелен на США. Следует так же отметить, что средняя стоимость привлечения клиентов по данному каналу не очень большая.
# * так же часть затрат я предложил бы перенести на канал YRabbit,по которому стоимость привлчения пользователей одна из самых низких, и конверсию пользователей в 3,8 %.
#
# Почему я выбрал именно эти каналы: они полностью нацелены на пользователей США ( по которым работает канал TipTop, который показал свою неэффективность), и возможно переброс средств с TipTop на эти каналы, позволит привлечь большее количество пользователей ( чем через канал TipTop) , с меньшими затратами, с достаточно привлекателей конверсией.
